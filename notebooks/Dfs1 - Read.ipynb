# %%
from mikeio import Dfs1
import matplotlib.pyplot as plt

filename = r"../tests/testdata/random.dfs1"
dfs = Dfs1(filename)

dfs
# Out:
# <mikeio.Dfs1>
# dx: 100.00000
# Items:
#   0:  testing water level <Water Level> (meter)
# Time: 100 steps
# Start time: 2012-01-01 00:00:00

# %%
ds = dfs.read()
ds
# Out:
# <mikeio.Dataset>
# Dimensions: (100, 3)
# Time: 2012-01-01 00:00:00 - 2012-01-01 00:19:48
# Items:
#   0:  testing water level <Water Level> (meter)

# %%
wl = ds[0].to_numpy()

# %%
wl.shape
# Out:
# (100, 3)

# %%
plt.plot(ds.time, wl[:,0], label="First")
plt.plot(ds.time, wl[:,-1], label="Last")
plt.ylabel(ds.items[0])
plt.legend()
