# %%
import mikeio

ds = mikeio.read("../tests/testdata/random.dfs1")
ds
# Out:
# <mikeio.Dataset>
# Dimensions: (time:100, x:3)
# Time: 2012-01-01 00:00:00 - 2012-01-01 00:19:48 (100 records)
# Items:
#   0:  testing water level <Water Level> (meter)

# %%
da = ds["testing water level"]

# %%
da.plot()
# Out:
# <AxesSubplot:xlabel='x', ylabel='testing water level [meter]'>

# %%
da.isel(0).plot(title="First")
# Out:
# <AxesSubplot:title={'center':'First'}, xlabel='time', ylabel='testing water level [meter]'>

# %%
da.isel(-1).plot(title="Last")
# Out:
# <AxesSubplot:title={'center':'Last'}, xlabel='time', ylabel='testing water level [meter]'>

# %% [markdown]
# Export a single point from the Dfs1 to Dfs0

# %%
da.isel(0).to_dfs("random_0.dfs0")
# Out:
# c:\users\jan\code\mikeio\mikeio\dataset.py:378: FutureWarning: property data is deprecated
#   warnings.warn(

# %%
mikeio.read("random_0.dfs0")[0].plot()
# Out:
# <AxesSubplot:xlabel='time', ylabel='testing water level [meter]'>

# %%
import os
os.remove("random_0.dfs0")
