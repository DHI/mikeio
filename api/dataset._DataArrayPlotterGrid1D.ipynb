# %% [markdown]
# #
#
# # dataset.\_DataArrayPlotterGrid1D
#
# ``` python
# dataset._DataArrayPlotterGrid1D(self, da)
# ```
#
# Plot a DataArray with a Grid1D geometry.
#
# ## Examples
#
# ``` python
# >>> da = mikeio.read("tide1.dfs1")["Level"]
# >>> da.plot()
# >>> da.plot.line()
# >>> da.plot.timeseries()
# >>> da.plot.imshow()
# >>> da.plot.pcolormesh()
# >>> da.plot.hist()
# ```
#
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [hist](#mikeio.dataset._DataArrayPlotterGrid1D.hist) | Plot DataArray as histogram (using ax.hist). |
# | [imshow](#mikeio.dataset._DataArrayPlotterGrid1D.imshow) | Plot as 2d. |
# | [line](#mikeio.dataset._DataArrayPlotterGrid1D.line) | Plot as spatial lines. |
# | [pcolormesh](#mikeio.dataset._DataArrayPlotterGrid1D.pcolormesh) | Plot multiple lines as 2d color plot. |
# | [timeseries](#mikeio.dataset._DataArrayPlotterGrid1D.timeseries) | Plot as timeseries. |
#
# ### hist
#
# ``` python
# dataset._DataArrayPlotterGrid1D.hist(
#     ax=None,
#     figsize=None,
#     title=None,
#     **kwargs,
# )
# ```
#
# Plot DataArray as histogram (using ax.hist).
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |----|--------|---------------------------------------------------------|----|
# | bins | (int or sequence or str,) | If bins is an integer, it defines the number of equal-width bins in the range. If bins is a sequence, it defines the bin edges, including the left edge of the first bin and the right edge of the last bin. by default: rcParams\[“hist.bins”\] (default: 10) | *required* |
# | ax | Axes \| None | Adding to existing axis, instead of creating new fig | `None` |
# | figsize | tuple\[float, float\] \| None | specify size of figure | `None` |
# | title | str \| None | axes title | `None` |
# | \*\*kwargs | Any | additional arguments passed to the plotting function | `{}` |
#
# #### See Also
#
# matplotlib.pyplot.hist
#
# #### Returns
#
# | Name | Type                | Description |
# |------|---------------------|-------------|
# |      | \<matplotlib.axes\> |             |
#
# ### imshow
#
# ``` python
# dataset._DataArrayPlotterGrid1D.imshow(ax=None, figsize=None, **kwargs)
# ```
#
# Plot as 2d.
#
# ### line
#
# ``` python
# dataset._DataArrayPlotterGrid1D.line(ax=None, figsize=None, **kwargs)
# ```
#
# Plot as spatial lines.
#
# ### pcolormesh
#
# ``` python
# dataset._DataArrayPlotterGrid1D.pcolormesh(
#     ax=None,
#     figsize=None,
#     title=None,
#     **kwargs,
# )
# ```
#
# Plot multiple lines as 2d color plot.
#
# ### timeseries
#
# ``` python
# dataset._DataArrayPlotterGrid1D.timeseries(ax=None, figsize=None, **kwargs)
# ```
#
# Plot as timeseries.
