# %% [markdown]
# #
#
# # spatial.GeometryFMVerticalColumn
#
# ``` python
# spatial.GeometryFMVerticalColumn(
#     self,
#     *,
#     node_coordinates,
#     element_table,
#     codes=None,
#     projection='LONG/LAT',
#     dfsu_type=DfsuFileType.Dfsu3DSigma,
#     element_ids=None,
#     node_ids=None,
#     n_layers=1,
#     n_sigma=None,
#     validate=True,
#     reindex=False,
# )
# ```
#
# A 3d geometry with consisting of a single vertical column.
#
# ## Attributes
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [bottom_elements](#mikeio.spatial.GeometryFMVerticalColumn.bottom_elements) | List of 3d element ids of bottom layer. |
# | [boundary_codes](#mikeio.spatial.GeometryFMVerticalColumn.boundary_codes) | Unique list of boundary codes. |
# | [codes](#mikeio.spatial.GeometryFMVerticalColumn.codes) | Node codes of all nodes (0=water, 1=land, 2…=open boundaries). |
# | [e2_e3_table](#mikeio.spatial.GeometryFMVerticalColumn.e2_e3_table) | The 2d-to-3d element connectivity table for a 3d object. |
# | [elem2d_ids](#mikeio.spatial.GeometryFMVerticalColumn.elem2d_ids) | The associated 2d element id for each 3d element. |
# | [element_coordinates](#mikeio.spatial.GeometryFMVerticalColumn.element_coordinates) | Center coordinates of each element. |
# | [is_geo](#mikeio.spatial.GeometryFMVerticalColumn.is_geo) | Are coordinates geographical (LONG/LAT)? |
# | [is_local_coordinates](#mikeio.spatial.GeometryFMVerticalColumn.is_local_coordinates) | Are coordinates relative (NON-UTM)? |
# | [layer_ids](#mikeio.spatial.GeometryFMVerticalColumn.layer_ids) | The layer number (0=bottom, 1, 2, …) for each 3d element. |
# | [max_nodes_per_element](#mikeio.spatial.GeometryFMVerticalColumn.max_nodes_per_element) | The maximum number of nodes for an element. |
# | [n_elements](#mikeio.spatial.GeometryFMVerticalColumn.n_elements) | Number of 3d elements. |
# | [n_layers](#mikeio.spatial.GeometryFMVerticalColumn.n_layers) | Maximum number of layers. |
# | [n_layers_per_column](#mikeio.spatial.GeometryFMVerticalColumn.n_layers_per_column) | List of number of layers for each column. |
# | [n_sigma_layers](#mikeio.spatial.GeometryFMVerticalColumn.n_sigma_layers) | Number of sigma layers. |
# | [n_z_layers](#mikeio.spatial.GeometryFMVerticalColumn.n_z_layers) | Maximum number of z-layers. |
# | [projection](#mikeio.spatial.GeometryFMVerticalColumn.projection) | The projection. |
# | [projection_string](#mikeio.spatial.GeometryFMVerticalColumn.projection_string) | The projection string. |
# | [top_elements](#mikeio.spatial.GeometryFMVerticalColumn.top_elements) | List of 3d element ids of surface layer. |
#
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [get_layer_elements](#mikeio.spatial.GeometryFMVerticalColumn.get_layer_elements) | 3d element ids for one (or more) specific layer(s). |
# | [get_space_axis](#mikeio.spatial.GeometryFMVerticalColumn.get_space_axis) | Get geographic space axis indices within the geometry’s dims. |
# | [reduce](#mikeio.spatial.GeometryFMVerticalColumn.reduce) | Return reduced geometry after spatial aggregation. |
# | [to_2d_geometry](#mikeio.spatial.GeometryFMVerticalColumn.to_2d_geometry) | extract 2d geometry from 3d geometry. |
#
# ### get_layer_elements
#
# ``` python
# spatial.GeometryFMVerticalColumn.get_layer_elements(layers)
# ```
#
# 3d element ids for one (or more) specific layer(s).
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |-----|----------|---------------------------------------------------|-------|
# | layers | int or list(int) | layer between 0 (bottom) and n_layers-1 (top) (can also be negative counting from -1 at the top layer) | *required* |
#
# #### Returns
#
# | Name | Type          | Description |
# |------|---------------|-------------|
# |      | np.array(int) | element ids |
#
# ### get_space_axis
#
# ``` python
# spatial.GeometryFMVerticalColumn.get_space_axis()
# ```
#
# Get geographic space axis indices within the geometry’s dims.
#
# Returns which of the geometry’s dims represent geographic space
# dimensions, as opposed to spectral or other non-geographic dimensions.
#
# This is used when axis=“space” or axis=“spatial” is specified in
# operations like aggregate, mean, etc.
#
# #### Returns
#
# | Name | Type | Description |
# |----|--------|------------------------------------------------------------|
# |  | tuple\[int, …\] | Space axis indices (0-indexed within geometry.dims). Returns empty tuple if there are no space dimensions (e.g., point geometries, pure spectral geometries). |
#
# #### Examples
#
# Grid2D with dims=(“y”, “x”) returns (0, 1) - both are space.
# GeometryFMAreaSpectrum with dims=(“element”, “direction”, “frequency”)
# returns (0,) - only element is space, direction/frequency are spectral.
# GeometryFMPointSpectrum with dims=(“frequency”,) returns () - no space.
#
# ### reduce
#
# ``` python
# spatial.GeometryFMVerticalColumn.reduce(axis)
# ```
#
# Return reduced geometry after spatial aggregation.
#
# ### to_2d_geometry
#
# ``` python
# spatial.GeometryFMVerticalColumn.to_2d_geometry()
# ```
#
# extract 2d geometry from 3d geometry.
#
# #### Returns
#
# | Name | Type         | Description |
# |------|--------------|-------------|
# |      | GeometryFM2D | 2d geometry |
