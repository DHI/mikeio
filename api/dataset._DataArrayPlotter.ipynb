# %% [markdown]
# #
#
# # dataset.\_DataArrayPlotter
#
# ``` python
# dataset._DataArrayPlotter(self, da)
# ```
#
# Context aware plotter (sensible plotting according to geometry).
#
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [hist](#mikeio.dataset._DataArrayPlotter.hist) | Plot DataArray as histogram (using ax.hist). |
# | [line](#mikeio.dataset._DataArrayPlotter.line) | Plot data as lines (timeseries if time is present). |
#
# ### hist
#
# ``` python
# dataset._DataArrayPlotter.hist(
#     bins=None,
#     ax=None,
#     figsize=None,
#     title=None,
#     **kwargs,
# )
# ```
#
# Plot DataArray as histogram (using ax.hist).
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |----|--------|---------------------------------------------------------|----|
# | bins | (int or sequence or str,) | If bins is an integer, it defines the number of equal-width bins in the range. If bins is a sequence, it defines the bin edges, including the left edge of the first bin and the right edge of the last bin. by default: rcParams\[“hist.bins”\] (default: 10) | `None` |
# | ax | Axes \| None | Adding to existing axis, instead of creating new fig | `None` |
# | figsize | tuple\[float, float\] \| None | specify size of figure | `None` |
# | title | str \| None | axes title | `None` |
# | \*\*kwargs | Any | additional arguments passed to the plotting function | `{}` |
#
# #### See Also
#
# matplotlib.pyplot.hist
#
# #### Returns
#
# | Name | Type                | Description |
# |------|---------------------|-------------|
# |      | \<matplotlib.axes\> |             |
#
# ### line
#
# ``` python
# dataset._DataArrayPlotter.line(ax=None, figsize=None, **kwargs)
# ```
#
# Plot data as lines (timeseries if time is present).
