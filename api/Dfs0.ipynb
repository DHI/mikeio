# %% [markdown]
# #
#
# # Dfs0
#
# ``` python
# Dfs0(self, filename)
# ```
#
# Class for reading/writing dfs0 files.
#
# ## Attributes
#
# | Name                                    | Description                |
# |-----------------------------------------|----------------------------|
# | [items](#mikeio.Dfs0.items)             | List of items.             |
# | [n_items](#mikeio.Dfs0.n_items)         | Number of items.           |
# | [n_timesteps](#mikeio.Dfs0.n_timesteps) | Number of time steps.      |
# | [start_time](#mikeio.Dfs0.start_time)   | File start time.           |
# | [time](#mikeio.Dfs0.time)               | File all datetimes.        |
# | [timestep](#mikeio.Dfs0.timestep)       | Time step size in seconds. |
#
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [read](#mikeio.Dfs0.read) | Read data from a dfs0 file. |
# | [to_dataframe](#mikeio.Dfs0.to_dataframe) | Read data from the dfs0 file and return a Pandas DataFrame. |
#
# ### read
#
# ``` python
# Dfs0.read(items=None, time=None, **kwargs)
# ```
#
# Read data from a dfs0 file.
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |-------|--------------------------|---------------------------------|-------|
# | items | str \| int \| Sequence\[str \| int\] \| None | Read only selected items, by number (0-based), or by name | `None` |
# | time | int \| str \| slice \| None | Read only selected time steps, by default None (=all) | `None` |
# | \*\*kwargs | Any | Additional keyword arguments are ignored | `{}` |
#
# #### Returns
#
# | Name | Type    | Description                          |
# |------|---------|--------------------------------------|
# |      | Dataset | A Dataset with data dimensions \[t\] |
#
# ### to_dataframe
#
# ``` python
# Dfs0.to_dataframe(unit_in_name=False, round_time='ms')
# ```
#
# Read data from the dfs0 file and return a Pandas DataFrame.
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |---------|------|---------------------------------------------------|-------|
# | unit_in_name | bool | include unit in column name, default False | `False` |
# | round_time | str | round time to avoid problem with floating point inaccurcy, set to False to avoid rounding | `'ms'` |
#
# #### Returns
#
# | Name | Type         | Description |
# |------|--------------|-------------|
# |      | pd.DataFrame |             |
