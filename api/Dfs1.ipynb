# %% [markdown]
# #
#
# # Dfs1
#
# ``` python
# Dfs1(self, filename)
# ```
#
# Class for reading/writing dfs1 files.
#
# ## Attributes
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [deletevalue](#mikeio.Dfs1.deletevalue) | File delete value. |
# | [dx](#mikeio.Dfs1.dx) | Step size in x direction. |
# | [end_time](#mikeio.Dfs1.end_time) | File end time. |
# | [is_geo](#mikeio.Dfs1.is_geo) | Are coordinates geographical (LONG/LAT)? |
# | [items](#mikeio.Dfs1.items) | List of items. |
# | [latitude](#mikeio.Dfs1.latitude) | Origin latitude. |
# | [longitude](#mikeio.Dfs1.longitude) | Origin longitude. |
# | [n_items](#mikeio.Dfs1.n_items) | Number of items. |
# | [n_timesteps](#mikeio.Dfs1.n_timesteps) | Number of time steps. |
# | [nx](#mikeio.Dfs1.nx) | Number of node values. |
# | [orientation](#mikeio.Dfs1.orientation) | Orientation (in own CRS). |
# | [origin](#mikeio.Dfs1.origin) | Origin (in own CRS). |
# | [shape](#mikeio.Dfs1.shape) | Shape of the data array. |
# | [start_time](#mikeio.Dfs1.start_time) | File start time. |
# | [timestep](#mikeio.Dfs1.timestep) | Time step size in seconds. |
# | [x0](#mikeio.Dfs1.x0) | Start point of x values (often 0). |
#
# ## Methods
#
# | Name                      | Description                 |
# |---------------------------|-----------------------------|
# | [read](#mikeio.Dfs1.read) | Read data from a dfs1 file. |
#
# ### read
#
# ``` python
# Dfs1.read(items=None, time=None, keepdims=False, dtype=np.float32)
# ```
#
# Read data from a dfs1 file.
#
# #### Parameters
#
# | Name | Type | Description | Default |
# |-----|------------------|-------------------------------------------|-------|
# | items | str \| int \| Sequence\[str \| int\] \| None | Read only selected items, by number (0-based), or by name | `None` |
# | time | int \| str \| slice \| None | Read only selected time steps, by default None (=all) | `None` |
# | keepdims | bool | When reading a single time step only, should the time-dimension be kept in the returned Dataset? by default: False | `False` |
# | dtype | Any | Define the dtype of the returned dataset (default = np.float32) | `np.float32` |
#
# #### Returns
#
# | Name | Type    | Description |
# |------|---------|-------------|
# |      | Dataset |             |
