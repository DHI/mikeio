# %% [markdown]
# # spatial.\_FM_geometry.\_GeometryFMPlotter
#
# ``` python
# spatial._FM_geometry._GeometryFMPlotter(self, geometry)
# ```
#
# Plot GeometryFM.
#
# ## Examples

# %%
import mikeio

ds = mikeio.read("../data/FakeLake.dfsu")
g = ds.geometry
g.plot()

# %% [markdown]
# ## Methods
#
# | Name | Description |
# |------------------------------------|------------------------------------|
# | [boundary_nodes](#mikeio.spatial._FM_geometry._GeometryFMPlotter.boundary_nodes) | Plot mesh boundary nodes and their code values. |
# | [contour](#mikeio.spatial._FM_geometry._GeometryFMPlotter.contour) | Plot bathymetry as contour lines. |
# | [contourf](#mikeio.spatial._FM_geometry._GeometryFMPlotter.contourf) | Plot bathymetry as filled contours. |
# | [mesh](#mikeio.spatial._FM_geometry._GeometryFMPlotter.mesh) | Plot mesh only. |
# | [outline](#mikeio.spatial._FM_geometry._GeometryFMPlotter.outline) | Plot domain outline. |
#
# ### boundary_nodes
#
# ``` python
# spatial._FM_geometry._GeometryFMPlotter.boundary_nodes(
#     boundary_names=None,
#     figsize=None,
#     ax=None,
# )
# ```
#
# Plot mesh boundary nodes and their code values.
#
# #### Examples

# %%
g.plot.boundary_nodes()

# %% [markdown]
# ### contour
#
# ``` python
# spatial._FM_geometry._GeometryFMPlotter.contour(ax=None, figsize=None, **kwargs)
# ```
#
# Plot bathymetry as contour lines.
#
# #### Examples

# %%
g.plot.contour()

# %% [markdown]
# ### contourf
#
# ``` python
# spatial._FM_geometry._GeometryFMPlotter.contourf(
#     ax=None,
#     figsize=None,
#     **kwargs,
# )
# ```
#
# Plot bathymetry as filled contours.
#
# #### Examples

# %%
g.plot.contourf()

# %% [markdown]
# ### mesh
#
# ``` python
# spatial._FM_geometry._GeometryFMPlotter.mesh(
#     title='Mesh',
#     figsize=None,
#     ax=None,
# )
# ```
#
# Plot mesh only.
#
# #### Examples

# %%
g.plot.mesh()

# %% [markdown]
# ### outline
#
# ``` python
# spatial._FM_geometry._GeometryFMPlotter.outline(
#     title='Outline',
#     figsize=None,
#     ax=None,
# )
# ```
#
# Plot domain outline.
#
# #### Examples

# %%
g.plot.outline()
